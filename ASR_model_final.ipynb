# %%
import librosa
import IPython.display
from playsound import playsound
from asr_model import get_prediction, record_audio #python script to get predicted transcribed audio
from info_extractor import print_info #python script to get operational info

# %%
#loading audio path
audio_path='audio_test/resampled_audio_100.wav'
data,rate = librosa.load(audio_path)
IPython.display.Audio(data, rate=rate,autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#getting prediction and operational info
prediction = get_prediction(audio_path)
print_info(prediction)
# Out:
# UTTERANCE    : northwest eleven seventy eight maintain speed one seven zero til ripit and contact the tower one one niner point one
# CALLSIGN     : NORTHWEST ELEVEN SEVENTY EIGHT
# COMMUNICATION: CONTACT the tower one one niner point one

# %%
#using record
print('Recording...')
record_audio()
print('Recording stopped...')
print('-'*100)

#getting prediction and operational info
prediction = get_prediction('recorded_audio.wav')
print_info(prediction)
# Out:
# Recording...
# Recording stopped...
# ----------------------------------------------------------------------------------------------------
# UTTERANCE    : thank maintain one seven zero til e descend contact the tower one one nine for one
# COMMUNICATION: CONTACT the tower one one nine
# FLIGHT LEVEL : DESCEND
